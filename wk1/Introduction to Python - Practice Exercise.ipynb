# %%
#Exercise homework during Week 1 4/30/2026

# %%
# Task 1: Variable Declaration and Data Types

# %%
int_var = 25
float_var = 5.9
str_var = "Han"
bool_var = True

print(int_var, type(int_var))
print(float_var, type(float_var))
print(str_var, type(str_var))
print(bool_var, type(bool_var))
# Out:
# 25 <class 'int'>
# 5.9 <class 'float'>
# Han <class 'str'>
# True <class 'bool'>

# %%
# Task 2: String Manipulation

# %%
sample_string = "Python programming is fun!"

print(sample_string.lower()) #Convert to lowercase
print(sample_string.replace("Python", "Data science")) #Replace part of the string
print(sample_string.split(",")) #Split into a list
# Out:
# python programming is fun!
# Data science programming is fun!
# ['Python programming is fun!']

# %%
# Task 3: Basic Operations

# %%
a, b = 10, 3

print(a + b, a - b, a * b, a / b, a % b, a ** b) #Arithmetic
print(a > b, a < b, a == b, a != b, a >= b, a <= b) #Comparison
print(a > 10 and b < 5, a < 10 or b > 5, not (a == b)) #Logical
# Out:
# 13 7 30 3.3333333333333335 1 1000
# True False False True True False
# False False True

# %%
# Task 4: Data Collections # Skip because have not discussed it in class.

# %%
# Task 5: Expression Combination

# %%
result = (int_var * float_var) / (a - b) + len(sample_string)
print("Final result:", result)
# Out:
# Final result: 47.07142857142857
