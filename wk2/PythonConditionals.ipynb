# %%
# Python Conditionals Exercise
# Professor discusses this exercise during Week 2 5/4/2026 class.
"""
In this exercise, you'll practice working with various types of conditional statements
in Python. Follow the instructions for each task and complete the code.
"""

# Task 1: Basic if Statement
# Write a function that checks if a number is positive and prints an appropriate message
def check_positive(number):
    # Your code here
    # If the number is positive (greater than 0), print "The number is positive"
    # Complete this code
    pass

# Test Task 1
print("Task 1 Test:")
check_positive(5)
check_positive(-2)
print()

# %%
def check_positive(number):
    if number >= 0:
        print("The number is positive")

# %%
# Test Task 1
print("Task 1 Test:")
check_positive(number=5) # Expected output: The number is positive
check_positive(0)        # Expected output: The number is positive
# Out:
# Task 1 Test:
# The number is positive
# The number is positive

# %%
# Test Task 1
print("Task 1 Test:")
check_positive(-2) # Expected output: (nothing because did not enter a message for this)
# Out:
# Task 1 Test:

# %%
# Task 2: if-else Statement
# Write a function that determines if a student passed or failed based on their score
# A score of 60 or higher is a pass
def check_pass_fail(score):
    # Your code here
    # Use an if-else statement to print "Pass" or "Fail" based on the score
    # Complete this code
    pass

# Test Task 2
print("Task 2 Test:")
check_pass_fail(75)
check_pass_fail(45)
print()

# %%
def check_pass_fail(score):
    if score >= 60:
        print("Pass")
    else:
        print("Fail")

# %%
# Test Task 2
print("Task 2 Test:")
check_pass_fail(75) # Expected output: Pass
# Out:
# Task 2 Test:
# Pass

# %%
# Test Task 2
print("Task 2 Test:")
check_pass_fail(45) # Expected output: Fail
# Out:
# Task 2 Test:
# Fail

# %%
# Task 3: if-elif-else Statement
# Write a function that converts a numeric grade to a letter grade
# 90-100: A, 80-89: B, 70-79: C, 60-69: D, Below 60: F
def convert_to_letter_grade(score):
    # Your code here
    # Use if-elif-else to determine and return the correct letter grade
    # Complete this code
    pass

# Test Task 3
print("Task 3 Test:")
print(f"85 points is a {convert_to_letter_grade(85)} grade")
print(f"92 points is a {convert_to_letter_grade(92)} grade")
print(f"75 points is a {convert_to_letter_grade(75)} grade")
print(f"65 points is a {convert_to_letter_grade(65)} grade")
print(f"55 points is a {convert_to_letter_grade(55)} grade")
print()

# %%
def convert_to_letter_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

# %%
# Test Task 3
print("Task 3 Test:")
print(f"85 points is a {convert_to_letter_grade(85)} grade")
print(f"92 points is a {convert_to_letter_grade(92)} grade")
print(f"75 points is a {convert_to_letter_grade(75)} grade")
print(f"65 points is a {convert_to_letter_grade(65)} grade")
#print(f"55 points is a {convert_to_letter_grade(55)} grade")
# Out:
# Task 3 Test:
# 85 points is a B grade
# 92 points is a A grade
# 75 points is a C grade
# 65 points is a D grade

# %%
# Task 4: Nested Conditionals
# Write a function that determines whether a user can access a website based on:
# 1. Whether they are logged in (True/False)
# 2. Whether they are an admin (True/False)
# 3. Whether they have paid for premium content (True/False)
def check_access(is_logged_in, is_admin, is_premium):
    # Your code here
    # Using nested conditionals:
    # - If not logged in, print "Please log in to access the site"
    # - If logged in and admin, print "Welcome admin! Full access granted"
    # - If logged in, not admin, but premium, print "Welcome premium user! Premium content access granted"
    # - If logged in, not admin, not premium, print "Welcome! Basic access granted"
    # Complete this code
    pass

# Test Task 4
print("Task 4 Test:")
check_access(False, False, False)  # Not logged in
check_access(True, True, False)    # Logged in as admin
check_access(True, False, True)    # Logged in as premium user
check_access(True, False, False)   # Logged in as basic user
print()

# %%
def check_access(is_logged_in, is_admin, is_premium):
    # Outer conditional: Check if the user is even logged in first
    if is_logged_in:
        # Inner conditional: Now that we know they are logged in, check roles
        if is_admin:
            print("Welcome admin! Full access granted")
        elif is_premium:
            print("Welcome premium user! Premium content access granted")
        else:
            print("Welcome! Basic access granted")
    else:
        # This belongs to the outer "if", triggered if is_logged_in is False
        print("Please log in to access the site")

# %%
# Test Task 4
print("Task 4 Test:")
check_access(False, False, False)
# Out:
# Task 4 Test:
# Please log in to access the site

# %%
# Test Task 4
print("Task 4 Test:")
check_access(True, True, False)
# Out:
# Task 4 Test:
# Welcome admin! Full access granted

# %%
# Test Task 4
print("Task 4 Test:")
check_access(True, False, True)
# Out:
# Task 4 Test:
# Welcome premium user! Premium content access granted

# %%
# Test Task 4
print("Task 4 Test:")
check_access(True, False, False)
# Out:
# Task 4 Test:
# Welcome! Basic access granted

# %%
# Test Task 4
# combine test
print("Task 4 Test:")
check_access(None, False, False) # Expected Output: Please log in to access the site
check_access(True, True, False)  # Expected Output: Welcome admin! Full access granted
check_access(True, False, True)  # Expected Output: Welcome premium user! Premium content access granted
check_access(True, False, False) # Expected Output: Welcome! Basic access granted
# Out:
# Task 4 Test:
# Please log in to access the site
# Welcome admin! Full access granted
# Welcome premium user! Premium content access granted
# Welcome! Basic access granted

# %%
# Proving "Falsy" values (prof's example)
print(f"Empty list []: {bool([])}")  # Output: False
print(f"The number 0: {bool(0)}")    # Output: False
print(f"None value: {bool(None)}")   # Output: False

# Proving "Truthy" values (prof's example)
print(f"List with data: {bool([1, 2])}")  # Output: True
print(f"The number 10: {bool(10)}")       # Output: True
print(f"A string 'Hi': {bool('Hi')}")     # Output: True
# Out:
# Empty list []: False
# The number 0: False
# None value: False
# List with data: True
# The number 10: True
# A string 'Hi': True

# %%
# Task 5: Ternary Operator
# Use the ternary operator to write a compact function that returns "Even" or "Odd"
# based on whether a number is divisible by 2
def check_even_odd(number):
    # Your code here
    # Use the ternary operator to return "Even" or "Odd"
    # Complete this code in a single line
    pass

# Test Task 5
print("Task 5 Test:")
print(f"5 is {check_even_odd(5)}")
print(f"8 is {check_even_odd(8)}")
print()

# %%
def check_even_odd(number):
    return "Even" if number % 2 == 0 else "Odd"

# %%
# Test Task 5
print("Task 5 Test:")
print(f"5 is {check_even_odd(5)}") # Output: 5 is Odd
print(f"8 is {check_even_odd(8)}") # Output: 8 is Even
# Out:
# Task 5 Test:
# 5 is Odd
# 8 is Even

# %%
# Task 6: Combining Conditions
# Write a function that determines if a year is a leap year
# A leap year is divisible by 4, except for years divisible by 100 unless they are also divisible by 400
def is_leap_year(year):
    # Your code here
    # Use logical operators (and, or, not) to combine conditions and return True or False
    # Complete this code
    pass

# Test Task 6
print("Task 6 Test:")
print(f"2020 is a leap year: {is_leap_year(2020)}")
print(f"2000 is a leap year: {is_leap_year(2000)}")
print(f"1900 is a leap year: {is_leap_year(1900)}")
print(f"2022 is a leap year: {is_leap_year(2022)}")
print()

# %%
# write directly with if statements:
def is_leap_year(year):
    if year % 400 == 0:
        return True
    elif year % 100 == 0:
        return False
    elif year % 4 == 0:
        return True
    else:
        return False

# %%
# Test Task 6
print("Task 6 Test:")
print(f"2020 is a leap year: {is_leap_year(2020)}") # Expected Output: True
print(f"2000 is a leap year: {is_leap_year(2000)}") # Expected Output: True
print(f"1900 is a leap year: {is_leap_year(1900)}") # Expected Output: False
print(f"2022 is a leap year: {is_leap_year(2022)}") # Expected Output: False
print()
# Out:
# Task 6 Test:
# 2020 is a leap year: True
# 2000 is a leap year: True
# 1900 is a leap year: False
# 2022 is a leap year: False

# %%
# or can combine the conditions into one line:
# Read this in plain English: "A year is a leap year if it is divisible by 4 and not divisible by 100, or it is divisible by 400."
def is_leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

# %%
# Test Task 6
print("Task 6 Test:")
print(f"2020 is a leap year: {is_leap_year(2020)}") # Expected Output: True
print(f"2000 is a leap year: {is_leap_year(2000)}") # Expected Output: True
print(f"1900 is a leap year: {is_leap_year(1900)}") # Expected Output: False
print(f"2022 is a leap year: {is_leap_year(2022)}") # Expected Output: False
print(f"2026 is a leap year: {is_leap_year(2026)}") # Expected Output: False
# Out:
# Task 6 Test:
# 2020 is a leap year: True
# 2000 is a leap year: True
# 1900 is a leap year: False
# 2022 is a leap year: False
# 2026 is a leap year: False

# %%
# Task 7: Best Practices
# Refactor the following code to make it more readable and efficient
def classify_item(item_type, price, in_stock):
    result = ""
    if item_type == "electronics":
        if price < 100:
            if in_stock == True:
                result = "Affordable electronics in stock"
            else:
                result = "Affordable electronics out of stock"
        else:
            if in_stock == True:
                result = "Premium electronics in stock"
            else:
                result = "Premium electronics out of stock"
    else:
        if price < 100:
            if in_stock == True:
                result = "Affordable non-electronics in stock"
            else:
                result = "Affordable non-electronics out of stock"
        else:
            if in_stock == True:
                result = "Premium non-electronics in stock"
            else:
                result = "Premium non-electronics out of stock"
    return result

# Test Task 7 with the current implementation
print("Task 7 Test (Original):")
print(classify_item("electronics", 75, True))
print(classify_item("electronics", 150, False))
print(classify_item("clothing", 50, False))
print()

# Your improved classify_item function
def improved_classify_item(item_type, price, in_stock):
    # Your code here
    # Rewrite the function above to be more readable and efficient
    # Use appropriate conditional structures, logic, and clear naming
    # Complete this code
    pass

# Test Task 7 with your improved implementation
print("Task 7 Test (Improved):")
print(improved_classify_item("electronics", 75, True))
print(improved_classify_item("electronics", 150, False))
print(improved_classify_item("clothing", 50, False))
print()

# %%
# Write the improved function
def improved_classify_item(item_type, price, in_stock):
    # Determine the item category
    category = "electronics" if item_type == "electronics" else "non-electronics"
    # Determine the price category
    price_level = "Affordable" if price < 100 else "Premium"
    # Determine stock status
    stock_status = "in stock" if in_stock else "out of stock"
    return f"{price_level} {category} {stock_status}"

# %%
# Test Task 7 with improved implementation
print("Task 7 Test (Improved):")
print(improved_classify_item("electronics", 75, True))   # Expected Output: Affordable electronics in stock
print(improved_classify_item("electronics", 150, False)) # Expected Output: Premium electronics out of stock
print(improved_classify_item("clothing", 50, False))     # Expected Output: Affordable non-electronics out of stock
print()
# Out:
# Task 7 Test (Improved):
# Affordable electronics in_stock
# Premium electronics out of stock
# Affordable non-electronics out of stock

# %%
# or write with if statements:
def improved_classify_item(item_type, price, in_stock):
    if item_type == "electronics":
        category = "electronics"
    else:
        category = "non-electronics"

    if price < 100:
        price_level = "Affordable"
    else:
        price_level = "Premium"

    if in_stock:
        stock_status = "in_stock"
    else:
        stock_status = "out of stock"

    return f"{price_level} {category} {stock_status}"

# %%
# Test Task 7 with improved implementation using if statements
print("Task 7 Test (Improved):")
print(improved_classify_item("electronics", 75, True))   # Expected Output: Affordable electronics in stock
print(improved_classify_item("electronics", 150, False)) # Expected Output: Premium electronics out of stock
print(improved_classify_item("clothing", 50, False))     # Expected Output: Affordable non-electronics out of stock
# Out:
# Task 7 Test (Improved):
# Affordable electronics in_stock
# Premium electronics out of stock
# Affordable non-electronics out of stock
